# %%
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8")

# %%
# Dependencies
import openweathermapy.core as owm
import json
from citipy import citipy
import pandas as pd
import requests
import random as random
import matplotlib.pyplot as plt

api_key = '4a313f88ffabce0a2caeea2d23fe9ace'

# %%
# set limit variables
max_long = 90
min_long = -90
max_lat = 180
min_lat = -180
step = 1

settings = {"units": "imperial", "appid": api_key}

# %%
#Generate random longitude and latitude
rand_long = random.randrange(min_long, max_long, step)
rand_lat = random.randrange(min_lat, max_lat, step)

rand_lat
# Out:
# -175

# %%
city = citipy.nearest_city(rand_long, rand_lat)
city.city_name
# Out:
# 'vaini'

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "London"
print('hello')
# Out:
# hello

# %%
summary = ["name", "main.temp", "main.humidity","clouds.all", "wind.speed", "coord.lon", "coord.lat"]

# create counter
counter = 0
cities = []
weather = []


#create list of 500 unique cities that are searchable on weather API
while counter < 500:
    rand_long = random.randrange(min_long, max_long, step)
    rand_lat = random.randrange(min_lat, max_lat, step)
    city = citipy.nearest_city(rand_long, rand_lat)
    #if city not in list, add it 
    if (city.city_name in cities):
        counter = counter + 0
    else:
        #try except 
            try:
                current_weather = owm.get_current(str(city.city_name), **settings)
                data = current_weather(*summary)
                print('Processing city ' + (str(city.city_name)) + "...")
                cities.append(str(city.city_name))
                counter = counter + 1
                #print(counter)
            except:
                counter = counter + 0
                #print('not found')
# Out:
# Processing city vaihingen...
# Processing city lewiston...
# Processing city port alfred...
# Processing city rikitea...
# Processing city nouakchott...
# Processing city cockburn town...
# Processing city whitehorse...
# Processing city qaanaaq...
# Processing city punta arenas...
# Processing city cape town...
# Processing city bethel...
# Processing city arraial do cabo...
# Processing city sijunjung...
# Processing city san cristobal...
# Processing city eten...
# Processing city tessalit...
# Processing city ushuaia...
# Processing city rafai...
# Processing city yellowknife...
# Processing city taltal...
# Processing city bela...
# Processing city hilo...
# Processing city russell...
# Processing city bambous virieux...
# Processing city yuzhno-kurilsk...
# Processing city chuy...
# Processing city aksu...
# Processing city gobabis...
# Processing city bredasdorp...
# Processing city lompoc...
# Processing city albany...
# Processing city hithadhoo...
# Processing city marienburg...
# Processing city trairi...
# Processing city roald...
# Processing city puerto ayora...
# Processing city atuona...
# Processing city torbay...
# Processing city victoria...
# Processing city calmar...
# Processing city san patricio...
# Processing city jacareacanga...
# Processing city kapaa...
# Processing city east london...
# Processing city mehamn...
# Processing city mount gambier...
# Processing city sioux lookout...
# Processing city busselton...
# Processing city george town...
# Processing city sao jose da coroa grande...
# Processing city carnarvon...
# Processing city bazarnyye mataki...
# Processing city gimli...
# Processing city rocha...
# Processing city canton...
# Processing city mataura...
# Processing city clyde river...
# Processing city pevek...
# Processing city sitka...
# Processing city arroyo...
# Processing city chokurdakh...
# Processing city verkhovazhye...
# Processing city esperance...
# Processing city khandagayty...
# Processing city coari...
# Processing city gboko...
# Processing city port blair...
# Processing city bahia blanca...
# Processing city concepcion del uruguay...
# Processing city moses lake...
# Processing city nabire...
# Processing city tateyama...
# Processing city yerbogachen...
# Processing city chaiyaphum...
# Processing city wenchi...
# Processing city egvekinot...
# Processing city salina...
# Processing city arantangi...
# Processing city padang...
# Processing city la ronge...
# Processing city kutum...
# Processing city rairangpur...
# Processing city vanavara...
# Processing city okha...
# Processing city plouzane...
# Processing city vanimo...
# Processing city medicine hat...
# Processing city shimoda...
# Processing city north bend...
# Processing city narsaq...
# Processing city ouidah...
# Processing city ribas do rio pardo...
# Processing city shchors...
# Processing city quincy...
# Processing city yumen...
# Processing city vinh...
# Processing city owando...
# Processing city los llanos de aridane...
# Processing city ntcheu...
# Processing city matelica...
# Processing city kyle...
# Processing city zhuhai...
# Processing city trinidad...
# Processing city victor harbor...
# Processing city ginir...
# Processing city ballina...
# Processing city filadelfia...
# Processing city naze...
# Processing city san rafael...
# Processing city letterkenny...
# Processing city dzilam gonzalez...
# Processing city gweta...
# Processing city keetmanshoop...
# Processing city desbiens...
# Processing city viedma...
# Processing city xixiang...
# Processing city broome...
# Processing city gushikawa...
# Processing city pangnirtung...
# Processing city lethem...
# Processing city huarmey...
# Processing city le port...
# Processing city kushiro...
# Processing city veraval...
# Processing city warwick...
# Processing city sainte-maxime...
# Processing city yeppoon...
# Processing city pimentel...
# Processing city grindavik...
# Processing city belmonte...
# Processing city cayenne...
# Processing city glasgow...
# Processing city turukhansk...
# Processing city mali...
# Processing city ahipara...
# Processing city namatanai...
# Processing city komsomolskiy...
# Processing city isla vista...
# Processing city lagoa...
# Processing city qaqortoq...
# Processing city jamame...
# Processing city orocue...
# Processing city solhan...
# Processing city constantine...
# Processing city swan hill...
# Processing city mgandu...
# Processing city touros...
# Processing city baykit...
# Processing city charagua...
# Processing city kjollefjord...
# Processing city laiyang...
# Processing city krasnoarmeysk...
# Processing city san juan...
# Processing city sao joao da barra...
# Processing city havoysund...
# Processing city missoula...
# Processing city yamada...
# Processing city makaryev...
# Processing city harrismith...
# Processing city xining...
# Processing city te anau...
# Processing city anqing...
# Processing city luderitz...
# Processing city morant bay...
# Processing city margate...
# Processing city roebourne...
# Processing city okhotsk...
# Processing city usinsk...
# Processing city wanaka...
# Processing city faya...
# Processing city vostok...
# Processing city ilulissat...
# Processing city pierre...
# Processing city koutsouras...
# Processing city ayan...
# Processing city kichera...
# Processing city okato...
# Processing city erzin...
# Processing city crib point...
# Processing city kloulklubed...
# Processing city arman...
# Processing city treinta y tres...
# Processing city boueni...
# Processing city ewo...
# Processing city oranjemund...
# Processing city shevchenkove...
# Processing city taber...
# Processing city yongzhou...
# Processing city marawi...
# Processing city creston...
# Processing city agirish...
# Processing city maragogi...
# Processing city katsuura...
# Processing city yulara...
# Processing city mezen...
# Processing city riyadh...
# Processing city baruun-urt...
# Processing city damaturu...
# Processing city russkiy aktash...
# Processing city podor...
# Processing city arkansas city...
# Processing city mahajanga...
# Processing city davila...
# Processing city kalevala...
# Processing city the valley...
# Processing city kamen-rybolov...
# Processing city atbasar...
# Processing city moroni...
# Processing city tomatlan...
# Processing city santiago del estero...
# Processing city misratah...
# Processing city abalak...
# Processing city general roca...
# Processing city serenje...
# Processing city tiznit...
# Processing city yangliuqing...
# Processing city sept-iles...
# Processing city chany...
# Processing city fairbanks...
# Processing city koumac...
# Processing city pauini...
# Processing city jian...
# Processing city puerto maldonado...
# Processing city araouane...
# Processing city byron bay...
# Processing city sovetskiy...
# Processing city buin...
# Processing city azul...
# Processing city muli...
# Processing city mana...
# Processing city mackay...
# Processing city port macquarie...
# Processing city dolores...
# Processing city pavino...
# Processing city haines junction...
# Processing city olovyannaya...
# Processing city wanxian...
# Processing city dabhol...
# Processing city cerro cama...
# Processing city prince rupert...
# Processing city la sarre...

# %%
cities
# Out:
# ['vaihingen',
#  'lewiston',
#  'port alfred',
#  'rikitea',
#  'nouakchott',
#  'cockburn town',
#  'whitehorse',
#  'qaanaaq',
#  'punta arenas',
#  'cape town',
#  'bethel',
#  'arraial do cabo',
#  'sijunjung',
#  'san cristobal',
#  'eten',
#  'tessalit',
#  'ushuaia',
#  'rafai',
#  'yellowknife',
#  'taltal',
#  'bela',
#  'hilo',
#  'russell',
#  'bambous virieux',
#  'yuzhno-kurilsk',
#  'chuy',
#  'aksu',
#  'gobabis',
#  'bredasdorp',
#  'lompoc',
#  'albany',
#  'hithadhoo',
#  'marienburg',
#  'trairi',
#  'roald',
#  'puerto ayora',
#  'atuona',
#  'torbay',
#  'victoria',
#  'calmar',
#  'san patricio',
#  'jacareacanga',
#  'kapaa',
#  'east london',
#  'mehamn',
#  'mount gambier',
#  'sioux lookout',
#  'busselton',
#  'george town',
#  'sao jose da coroa grande',
#  'carnarvon',
#  'bazarnyye mataki',
#  'gimli',
#  'rocha',
#  'canton',
#  'mataura',
#  'clyde river',
#  'pevek',
#  'sitka',
#  'arroyo',
#  'chokurdakh',
#  'verkhovazhye',
#  'esperance',
#  'khandagayty',
#  'coari',
#  'gboko',
#  'port blair',
#  'shenjiamen',
#  'cidreira',
#  'hobart',
#  'puerto ayacucho',
#  'jamestown',
#  'mar del plata',
#  'halifax',
#  'dasoguz',
#  'vaini',
#  'khorramshahr',
#  'bluff',
#  'cabo san lucas',
#  'hearst',
#  'kisangani',
#  'hermanus',
#  'bilma',
#  'cap malheureux',
#  'geraldton',
#  'port elizabeth',
#  'beringovskiy',
#  'qasigiannguit',
#  'alyangula',
#  'mega',
#  'lata',
#  'laguna',
#  'burns lake',
#  'san quintin',
#  'klaksvik',
#  'yar-sale',
#  'barrow',
#  'boa vista',
#  'alofi',
#  'tura',
#  'homer',
#  'pisco',
#  'drabiv',
#  'mecca',
#  'atambua',
#  'nikolskoye',
#  'arcachon',
#  'scarborough',
#  'chara',
#  'new norfolk',
#  'airai',
#  'broken hill',
#  'samarai',
#  'camargo',
#  'gat',
#  'sao borja',
#  'provideniya',
#  'pacifica',
#  'tairua',
#  'lorengau',
#  'sharjah',
#  'umm kaddadah',
#  'tasiilaq',
#  'labytnangi',
#  'salalah',
#  'butaritari',
#  'dzialdowo',
#  'vila franca do campo',
#  'college',
#  'lebu',
#  'pitimbu',
#  'talcahuano',
#  'terrace',
#  'sakaraha',
#  'strezhevoy',
#  'severo-kurilsk',
#  'bam',
#  'dikson',
#  'rio gallegos',
#  'thompson',
#  'ribeira grande',
#  'monrovia',
#  'rio grande',
#  'upernavik',
#  'rengo',
#  'port lincoln',
#  'kaitangata',
#  'buraydah',
#  'longyearbyen',
#  'saint-philippe',
#  'lakhisarai',
#  'kavieng',
#  'fredericton',
#  'abu dhabi',
#  'castro',
#  'thinadhoo',
#  'kruisfontein',
#  'eureka',
#  'dire',
#  'kapit',
#  'san luis',
#  'texarkana',
#  'hengshan',
#  'deep river',
#  'nome',
#  'khatanga',
#  'inongo',
#  'mangrol',
#  'westport',
#  'flinders',
#  'svetlogorsk',
#  'fort nelson',
#  'kodiak',
#  'jablanica',
#  'forbes',
#  'saint anthony',
#  'redwater',
#  'nanortalik',
#  'henties bay',
#  'killybegs',
#  'novopokrovka',
#  'sorong',
#  'souillac',
#  'subate',
#  'nagapattinam',
#  'talnakh',
#  'alice springs',
#  'saint george',
#  'tuatapere',
#  'ugoofaaru',
#  'soto la marina',
#  'cherskiy',
#  'chapais',
#  'port-gentil',
#  'tuktoyaktuk',
#  'karonga',
#  'saint-pierre',
#  'shieli',
#  'ferreira do alentejo',
#  'pacific grove',
#  'fortuna',
#  'ternate',
#  'mitsamiouli',
#  'hasaki',
#  'cortez',
#  'saskylakh',
#  'chegutu',
#  'aswan',
#  'kavaratti',
#  'qidong',
#  'rundu',
#  'wajir',
#  'coquimbo',
#  'avarua',
#  'aklavik',
#  'nemuro',
#  'la rioja',
#  'vilhena',
#  'trofors',
#  'ghanzi',
#  'kahului',
#  'soe',
#  'skibbereen',
#  'tiksi',
#  'sehithwa',
#  'umarkot',
#  'aloleng',
#  'tautira',
#  'palmer',
#  'kitob',
#  'san policarpo',
#  'bartlesville',
#  'portobelo',
#  'timra',
#  'biak',
#  'indiana',
#  'gornopravdinsk',
#  'utinga',
#  'mujiayingzi',
#  'saint-augustin',
#  'cassilandia',
#  'sur',
#  'kamaishi',
#  'canico',
#  'porangatu',
#  'coihaique',
#  'adiake',
#  'saldanha',
#  'kieta',
#  'mahebourg',
#  'isangel',
#  'yaring',
#  'atar',
#  'kholmy',
#  'manzhouli',
#  'sao filipe',
#  'evensk',
#  'great yarmouth',
#  'grand gaube',
#  'kununurra',
#  'waddan',
#  'shingu',
#  'ancud',
#  'codrington',
#  'collie',
#  'mount isa',
#  'nakhon ratchasima',
#  'pinawa',
#  'lasa',
#  'constitucion',
#  'nenjiang',
#  'kalmunai',
#  'hamilton',
#  'gandorhun',
#  'berlevag',
#  'axim',
#  'methoni',
#  'varangaon',
#  'georgetown',
#  'caravelas',
#  'vao',
#  'bakhmach',
#  'carutapera',
#  'sal rei',
#  'marzuq',
#  'northam',
#  'ponta do sol',
#  'farafangana',
#  'anzio',
#  'jumla',
#  'sattahip',
#  'nouadhibou',
#  'faanui',
#  'husavik',
#  'gamba',
#  'perleberg',
#  'vardo',
#  'elliot lake',
#  'tapiramuta',
#  'hami',
#  'jalu',
#  'port hedland',
#  'vallenar',
#  'iqaluit',
#  'kananga',
#  'dingle',
#  'gaillac',
#  'hirara',
#  'scottsboro',
#  'roma',
#  'verona',
#  'guerrero negro',
#  'paveh',
#  'dong hoi',
#  'bathsheba',
#  'imeni poliny osipenko',
#  'camacha',
#  'chateaubelair',
#  'half moon bay',
#  'manaus',
#  'machilipatnam',
#  'sola',
#  'vestmannaeyjar',
#  'lavrentiya',
#  'ola',
#  'havelock',
#  'bahia blanca',
#  'concepcion del uruguay',
#  'moses lake',
#  'nabire',
#  'tateyama',
#  'yerbogachen',
#  'chaiyaphum',
#  'wenchi',
#  'egvekinot',
#  'salina',
#  'arantangi',
#  'padang',
#  'la ronge',
#  'kutum',
#  'rairangpur',
#  'vanavara',
#  'okha',
#  'plouzane',
#  'vanimo',
#  'medicine hat',
#  'shimoda',
#  'north bend',
#  'narsaq',
#  'ouidah',
#  'ribas do rio pardo',
#  'shchors',
#  'quincy',
#  'yumen',
#  'vinh',
#  'owando',
#  'los llanos de aridane',
#  'ntcheu',
#  'matelica',
#  'kyle',
#  'zhuhai',
#  'trinidad',
#  'victor harbor',
#  'ginir',
#  'ballina',
#  'filadelfia',
#  'naze',
#  'san rafael',
#  'letterkenny',
#  'dzilam gonzalez',
#  'gweta',
#  'keetmanshoop',
#  'desbiens',
#  'viedma',
#  'xixiang',
#  'broome',
#  'gushikawa',
#  'pangnirtung',
#  'lethem',
#  'huarmey',
#  'le port',
#  'kushiro',
#  'veraval',
#  'warwick',
#  'sainte-maxime',
#  'yeppoon',
#  'pimentel',
#  'grindavik',
#  'belmonte',
#  'cayenne',
#  'glasgow',
#  'turukhansk',
#  'mali',
#  'ahipara',
#  'namatanai',
#  'komsomolskiy',
#  'isla vista',
#  'lagoa',
#  'qaqortoq',
#  'jamame',
#  'orocue',
#  'solhan',
#  'constantine',
#  'swan hill',
#  'mgandu',
#  'touros',
#  'baykit',
#  'charagua',
#  'kjollefjord',
#  'laiyang',
#  'krasnoarmeysk',
#  'san juan',
#  'sao joao da barra',
#  'havoysund',
#  'missoula',
#  'yamada',
#  'makaryev',
#  'harrismith',
#  'xining',
#  'te anau',
#  'anqing',
#  'luderitz',
#  'morant bay',
#  'margate',
#  'roebourne',
#  'okhotsk',
#  'usinsk',
#  'wanaka',
#  'faya',
#  'vostok',
#  'ilulissat',
#  'pierre',
#  'koutsouras',
#  'ayan',
#  'kichera',
#  'okato',
#  'erzin',
#  'crib point',
#  'kloulklubed',
#  'arman',
#  'treinta y tres',
#  'boueni',
#  'ewo',
#  'oranjemund',
#  'shevchenkove',
#  'taber',
#  'yongzhou',
#  'marawi',
#  'creston',
#  'agirish',
#  'maragogi',
#  'katsuura',
#  'yulara',
#  'mezen',
#  'riyadh',
#  'baruun-urt',
#  'damaturu',
#  'russkiy aktash',
#  'podor',
#  'arkansas city',
#  'mahajanga',
#  'davila',
#  'kalevala',
#  'the valley',
#  'kamen-rybolov',
#  'atbasar',
#  'moroni',
#  'tomatlan',
#  'santiago del estero',
#  'misratah',
#  'abalak',
#  'general roca',
#  'serenje',
#  'tiznit',
#  'yangliuqing',
#  'sept-iles',
#  'chany',
#  'fairbanks',
#  'koumac',
#  'pauini',
#  'jian',
#  'puerto maldonado',
#  'araouane',
#  'byron bay',
#  'sovetskiy',
#  'buin',
#  'azul',
#  'muli',
#  'mana',
#  'mackay',
#  'port macquarie',
#  'dolores',
#  'pavino',
#  'haines junction',
#  'olovyannaya',
#  'wanxian',
#  'dabhol',
#  'cerro cama',
#  'prince rupert',
#  'la sarre']

# %%
# Get current weather
summary = ["name", "main.temp", "main.humidity","clouds.all", "wind.speed", "coord.lon", "coord.lat"]

name = []
lon = []
lat = []
temp = []
humid = []
clouds = []
wind = []

for x in cities:
    current_weather = owm.get_current(x, **settings)
    data = current_weather(*summary)
    name.append(data[0])
    temp.append(data[1])
    humid.append(data[2])
    clouds.append(data[3])
    wind.append(data[4])
    lon.append(data[5])
    lat.append(data[6])
    
    #print(f"Current weather object for {x}: {current_weather}.")

print('done')

# %%
#build temp and lat dataframe for analysis
temperature = []
latitude = []

master = {
    'Name' : name,
    'Longitude' : lon,
    'Latitude' : lat,
    'Temperature (F)' : temp,
    'Humidity' : humid,
    'Cloudiness' : clouds,
    'Wind Speed' : wind}

yo = pd.DataFrame(master)
yo = yo.set_index("Name")
yo.head()

# %%
#Temperature (F) vs. Latitude
# note: if regression line is negative sloped, then winter is likely in the south hemisphere
import seaborn as sns; sns.set(color_codes=True)
ax = sns.regplot(x="Latitude", y="Temperature (F)", data=yo,fit_reg=True)
ax.set(xlim=(-90, 90))
plt.show()

# %%
bx = sns.regplot(x="Latitude", y="Humidity", data=yo,fit_reg=True)
bx.set(xlim=(-90, 90))
plt.show()

# %%
cx = sns.regplot(x="Latitude", y="Cloudiness", data=yo,fit_reg=True)
cx.set(xlim=(-90, 90))
plt.show()

# %%
dx = sns.regplot(x="Latitude", y="Wind", data=yo,fit_reg=True)
dx.set(xlim=(-90, 90))
plt.show()
